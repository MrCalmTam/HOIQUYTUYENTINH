# %% [markdown]
# <a href="https://colab.research.google.com/github/MrCalmTam/HOIQUYTUYENTINH/blob/main/AI17032023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (1.4.4)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.9/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas) (1.15.0)

# %%
import pandas as pd 
wl = '/content/mtcars.csv'
data=pd.read_csv(wl)
data.head()
# Out:
#           Unnamed: 0   mpg   disp   hp     wt
# 0          Mazda RX4  21.0  160.0  110  2.620
# 1      Mazda RX4 Wag  21.0  160.0  110  2.875
# 2         Datsun 710  22.8  108.0   93  2.320
# 3     Hornet 4 Drive  21.4  258.0  110  3.215
# 4  Hornet Sportabout  18.7  360.0  175  3.440

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data.hist()
plt.show()

# %%
corelation = data.corr()
print(corelation)
# Out:
#            mpg      disp        hp        wt
# mpg   1.000000 -0.847551 -0.776168 -0.867659
# disp -0.847551  1.000000  0.790949  0.887980
# hp   -0.776168  0.790949  1.000000  0.658748
# wt   -0.867659  0.887980  0.658748  1.000000

# %%
sns.pairplot(data)

# %%
sns.heatmap(corelation,annot=True)
# Out:
# <Axes: >

# %%
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='red')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='wt', ylabel='mpg'>

# %%
from sklearn import linear_model
model =linear_model.LinearRegression()
X = pd.DataFrame(data['wt'])
y = data['mpg']
model.fit(X ,y)
print('Gia tri Intercept la:',model.intercept_)
print('Gia tri Coeffient la:',model.coef_)
# Out:
# Gia tri Intercept la: 37.28512616734204
# Gia tri Coeffient la: [-5.34447157]

# %%
model.score(X,y )
# Out:
# 0.7528327936582646

# %%
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='red', )
y_pred=model.predict(X)
plt.plot(data['wt'],y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
X = pd.DataFrame([data['wt'], data['wt']**2]).T
model.fit(X,y=data['mpg'])
print('Gia tri Intercept la:',model.intercept_)
print('Gia tri Coeffient la:',model.coef_)
print(' do chinh xac cua mo hinh: ', model.score(X,y))
## y =13.38x + 1.17x^2+49.93 ; ddo chinh xac accazamy = 81%
# Out:
# Gia tri Intercept la: 49.93081094945181
# Gia tri Coeffient la: [-13.38033708   1.17108689]
#  do chinh xac cua mo hinh:  0.8190613581384094

# %%
import numpy as np
range=np.arange(1.5,5.5,0.1)
X_range=pd.DataFrame([range,range**2]).T
y_pred=model.predict(X_range)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
X = pd.DataFrame([data['wt'], data['wt']**3]).T
model.fit(X,y=data['mpg'])
print('Gia tri Intercept la:',model.intercept_)
print('Gia tri Coeffient la:',model.coef_)
print(' do chinh xac cua mo hinh: ', model.score(X,y)) 

import numpy as np
range=np.arange(1.5,5.5,0.1)
X_range=pd.DataFrame([range,range**3]).T
y_pred=model.predict(X_range)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# Gia tri Intercept la: 46.18691542897024
# Gia tri Coeffient la: [-9.58658863  0.1112848 ]
#  do chinh xac cua mo hinh:  0.8189918444632485
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
X = pd.DataFrame([data['wt'], data['wt']**4]).T
model.fit(X,y=data['mpg'])
print('Gia tri Intercept la:',model.intercept_)
print('Gia tri Coeffient la:',model.coef_)
print(' do chinh xac cua mo hinh: ', model.score(X,y))
import numpy as np
range=np.arange(1.5,5.5,0.1)
X_range=pd.DataFrame([range,range**4]).T
y_pred=model.predict(X_range)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# Gia tri Intercept la: 44.38411648986953
# Gia tri Coeffient la: [-8.35528565  0.01499455]
#  do chinh xac cua mo hinh:  0.8181290818435217
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
X = pd.DataFrame([data['wt'], data['wt']**5]).T
model.fit(X,y=data['mpg'])
print('Gia tri Intercept la:',model.intercept_)
print('Gia tri Coeffient la:',model.coef_)
print(' do chinh xac cua mo hinh: ', model.score(X,y))
import numpy as np
range=np.arange(1.5,5.5,0.1)
X_range=pd.DataFrame([range,range**5]).T
y_pred=model.predict(X_range)
data.plot(kind='scatter',x='wt',y='mpg',figsize=(9,9),color='black',xlim=(0,7))
plt.plot(range,y_pred,color='blue')
# Out:
# Gia tri Intercept la: 43.36121960046691
# Gia tri Coeffient la: [-7.76733717e+00  2.31835970e-03]
#  do chinh xac cua mo hinh:  0.8169282455035884
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %%
model =linear_model.LinearRegression()
Ax = data.loc[:,['wt']]
By = data['mpg']
model.fit(Ax ,By ) 
print('Gia tri Intercept la:',model.intercept_)
print('Gia tri Coeffient la:',model.coef_)
print(' do chinh xac cua mo hinh: ', model.score(Ax,By))
# Out:
# Gia tri Intercept la: 37.28512616734204
# Gia tri Coeffient la: [-5.34447157]
#  do chinh xac cua mo hinh:  0.7528327936582646

# %%
model =linear_model.LinearRegression()
Ax = data.loc[:,['wt','hp']]
By = data['mpg']
model.fit(Ax ,By ) 
print('Gia tri Intercept la:',model.intercept_)
print('Gia tri Coeffient la:',model.coef_)
print(' do chinh xac cua mo hinh: ', model.score(Ax,By)) 
## mpg = 3.87wt -0.03hp + 37.22
# Out:
# Gia tri Intercept la: 37.227270116447215
# Gia tri Coeffient la: [-3.87783074 -0.03177295]
#  do chinh xac cua mo hinh:  0.8267854518827914

# %%
model =linear_model.LinearRegression()
Ax = data.loc[:,['wt','hp','disp']]
By = data['mpg']
model.fit(Ax ,By ) 
print('Gia tri Intercept la:',model.intercept_)
print('Gia tri Coeffient la:',model.coef_)
print(' do chinh xac cua mo hinh: ', model.score(Ax,By))
# Out:
# Gia tri Intercept la: 37.10550526903184
# Gia tri Coeffient la: [-3.80089058e+00 -3.11565508e-02 -9.37009081e-04]
#  do chinh xac cua mo hinh:  0.8268361424946447

# %%
model =linear_model.LinearRegression()
Ax = data.loc[:,['wt','hp','disp']]
By = data['mpg']
model.fit(Ax ,By ) 
print('Gia tri Intercept la:',model.intercept_)
print('Gia tri Coeffient la:',model.coef_)
print(' do chinh xac cua mo hinh: ', model.score(Ax,By))

# %%
model =linear_model.LinearRegression()
Ax = data.loc[:,['wt']]
By = data['mpg']
model.fit(Ax ,By ) 
print('Gia tri Intercept la:',model.intercept_)
print('Gia tri Coeffient la:',model.coef_)
print(' do chinh xac cua mo hinh: ', model.score(Ax,By))
# Out:
# Gia tri Intercept la: 37.28512616734204
# Gia tri Coeffient la: [-5.34447157]
#  do chinh xac cua mo hinh:  0.7528327936582646
